# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head(100)
# Out:
#                    Producto  Categoría del Producto     Precio  \
# 0          Silla de oficina                 Muebles   283600.0
# 1                 Pandereta  Instrumentos musicales    76800.0
# 2                 Cama king                 Muebles   443300.0
# 3                 Cama king                 Muebles   906200.0
# 4          Silla de oficina                 Muebles   397800.0
# ..                      ...                     ...        ...
# 95        Asistente virtual            Electrónicos   275000.0
# 96            TV LED UHD 4K            Electrónicos  2677200.0
# 97          Sofá reclinable                 Muebles   732900.0
# 98                   Sillón                 Muebles   274000.0
# 99  Bloques de construcción                Juguetes    39600.0
#
#     Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0          15300.0      04/08/2021  Izabela de León        Medellín
# 1           2300.0      26/11/2020   Blanca Ramirez        Medellín
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %%
tienda4.isna().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Identificamos la facturacion
Ingresos_tienda = tienda["Precio"].sum()
Ingresos_tienda2 = tienda2["Precio"].sum()
Ingresos_tienda3 = tienda3["Precio"].sum()
Ingresos_tienda4 = tienda4["Precio"].sum()

df_ingresos = pd.DataFrame({
    "Tienda": ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"],
    "Ingresos": [Ingresos_tienda, Ingresos_tienda2, Ingresos_tienda3, Ingresos_tienda4]
}).set_index("Tienda")

# %%
ax = df_ingresos.plot(kind="bar", figsize=(8, 4), color="blue")

ax.set_xlabel("Ingresos")
ax.set_title("Ingresos por tienda")
ax.bar_label(ax.containers[0])

plt.show()

# %%
df_ingresos_mill = df_ingresos / 1_000_000

ax = df_ingresos_mill.plot(kind="bar", figsize=(8, 4), color="pink")
ax.set_ylabel("Ingresos (millones)")
ax.set_title("Ingresos por tienda")

ax.bar_label(ax.containers[0], fmt="%.2f")  # valores ya en millones

plt.show()

# %%
tienda['Precio']
# Out:
# 0        164300.0
# 1        192300.0
# 2        209600.0
# 3        757500.0
# 4        335200.0
#           ...
# 2354    1284400.0
# 2355     282800.0
# 2356     122900.0
# 2357     691300.0
# 2358     195000.0
# Name: Precio, Length: 2359, dtype: float64

# %% [markdown]
# # 2. Ventas por categoría

# %%
#Hallamos la cantidad de ventas por cada categoria de la tienda
tienda.groupby('Categoría del Producto')["Precio"].count()
# Out:
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# Name: Precio, dtype: int64

# %%
ventas_cat = (
    tienda
    .groupby('Categoría del Producto')["Precio"]
    .count()
    .sort_values(ascending=False)
)

print(ventas_cat)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Precio, dtype: int64

# %%
tiendas = {
    'tienda1': tienda,
    'tienda2': tienda2,
    'tienda3': tienda3,
    'tienda4': tienda4
}

resultados = {}

for nombre, df in tiendas.items():
    res = (
        df
        .groupby('Categoría del Producto')
        .agg(Cantidad_ventas=('Precio', 'count'))
        .sort_values('Cantidad_ventas', ascending=False)
    )
    resultados[nombre] = res
    print(f'\n=== {nombre} ===')
    print(res)
# Out:
# === tienda1 ===
#                          Cantidad_ventas
# Categoría del Producto
# Muebles                              465
# Electrónicos                         448
# Juguetes                             324
# Electrodomésticos                    312
# Deportes y diversión                 284
# Instrumentos musicales               182
# Libros                               173
# Artículos para el hogar              171
#
# === tienda2 ===
#                          Cantidad_ventas
# Categoría del Producto
# Muebles                              442
# Electrónicos                         422
# Juguetes                             313
# Electrodomésticos                    305
# Deportes y diversión                 275
# Instrumentos musicales               224
# Libros                               197
# Artículos para el hogar              181
#
# === tienda3 ===
#                          Cantidad_ventas
# Categoría del Producto
# Muebles                              499
# ...

# %%
res_list = []
for nombre, df in tiendas.items():
    tmp = (
        df
        .groupby('Categoría del Producto')
        .agg(Cantidad_ventas=('Precio', 'count'))
        .rename(columns={'Cantidad_ventas': nombre})
    )
    res_list.append(tmp)

comparacion = pd.concat(res_list, axis=1).fillna(0).astype(int)
print(comparacion)
# Out:
#                          tienda1  tienda2  tienda3  tienda4
# Categoría del Producto
# Artículos para el hogar      171      181      177      201
# Deportes y diversión         284      275      277      277
# Electrodomésticos            312      305      278      254
# Electrónicos                 448      422      451      451
# Instrumentos musicales       182      224      177      170
# Juguetes                     324      313      315      338
# Libros                       173      197      185      187
# Muebles                      465      442      499      480

# %%
comparacion['Total'] = comparacion.sum(axis=1)
comparacion = comparacion.sort_values('Total', ascending=False)
print(comparacion)
# Out:
#                          tienda1  tienda2  tienda3  tienda4  Total
# Categoría del Producto
# Muebles                      465      442      499      480   1886
# Electrónicos                 448      422      451      451   1772
# Juguetes                     324      313      315      338   1290
# Electrodomésticos            312      305      278      254   1149
# Deportes y diversión         284      275      277      277   1113
# Instrumentos musicales       182      224      177      170    753
# Libros                       173      197      185      187    742
# Artículos para el hogar      171      181      177      201    730

# %%
ventas1 = tienda.groupby("Categoría del Producto").size().rename("Tienda 1")
ventas2 = tienda2.groupby("Categoría del Producto").size().rename("Tienda 2")
ventas3 = tienda3.groupby("Categoría del Producto").size().rename("Tienda 3")
ventas4 = tienda4.groupby("Categoría del Producto").size().rename("Tienda 4")

# %%
df_ventas_categorias = pd.concat([ventas1, ventas2, ventas3, ventas4],axis=1).fillna(0).astype(int)
df_ventas_categorias.head()
# Out:
#                          Tienda 1  Tienda 2  Tienda 3  Tienda 4
# Categoría del Producto
# Artículos para el hogar       171       181       177       201
# Deportes y diversión          284       275       277       277
# Electrodomésticos             312       305       278       254
# Electrónicos                  448       422       451       451
# Instrumentos musicales        182       224       177       170

# %%
df_ventas_categorias.shape
# Out:
# (8, 4)

# %%
##Comparacion de las categorias mas vendidas por tienda
df_ventas_categorias["Total"] = df_ventas_categorias.sum(axis=1)
df_ventas_categorias = df_ventas_categorias.sort_values("Total", ascending=False)
df_ventas_categorias
# Out:
#                          Tienda 1  Tienda 2  Tienda 3  Tienda 4  Total
# Categoría del Producto
# Muebles                       465       442       499       480   1886
# Electrónicos                  448       422       451       451   1772
# Juguetes                      324       313       315       338   1290
# Electrodomésticos             312       305       278       254   1149
# Deportes y diversión          284       275       277       277   1113
# Instrumentos musicales        182       224       177       170    753
# Libros                        173       197       185       187    742
# Artículos para el hogar       171       181       177       201    730

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
#datos.groupby("Tipo")["Habitaciones"].mean()

# %%
print(tienda['Calificación'].mean())
# Out:
# 3.976685036032217

# %%
cal_t1 = tienda['Calificación'].mean()
cal_t2 = tienda2['Calificación'].mean()
cal_t3 = tienda3['Calificación'].mean()
cal_t4 = tienda4['Calificación'].mean()
df_cal = pd.DataFrame({
    "Tienda": ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"],
    "Calificacion": [cal_t1,cal_t2,cal_t3,cal_t4]
}).set_index("Tienda")
df_cal["Calificacion"] = df_cal["Calificacion"].round(2)

# %%
df_cal
# Out:
#           Calificacion
# Tienda
# Tienda 1          3.98
# Tienda 2          4.04
# Tienda 3          4.05
# Tienda 4          4.00

# %%
cx = df_cal.plot(kind= "bar",figsize = (8,4), color = "blue")
cx.set_xlabel("Calificación")
cx.set_title("Calificación por tienda")
cx.bar_label(cx.containers[0])
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
p_tienda1 = tienda.groupby("Producto")["Precio"].count().sort_values(ascending=False)
p_tienda1.head(5)
# Out:
# Producto
# Armario             60
# TV LED UHD 4K       60
# Microondas          60
# Secadora de ropa    58
# Mesa de noche       56
# Name: Precio, dtype: int64

# %%
p_tienda1.tail(5)
# Out:
# Producto
# Mochila                      39
# Pandereta                    36
# Olla de presión              35
# Celular ABXY                 33
# Auriculares con micrófono    33
# Name: Precio, dtype: int64

# %%
def top_y_bottom(df, nombre_tienda, n=5):
    conteo = (
        df.groupby("Producto")["Precio"]
          .count()
          .sort_values(ascending=False)
          .rename("Cantidad_ventas")
    )

    top_n = conteo.head(n)
    bottom_n = conteo.tail(n)

    # Los paso a DataFrame y agrego la columna Tienda para poder unir después
    top_n = top_n.reset_index()
    top_n["Tienda"] = nombre_tienda
    top_n["Tipo"] = "Más vendidos"

    bottom_n = bottom_n.reset_index()
    bottom_n["Tienda"] = nombre_tienda
    bottom_n["Tipo"] = "Menos vendidos"

    return top_n, bottom_n

# %%
tiendas = {
    "Tienda 1": tienda,
    "Tienda 2": tienda2,
    "Tienda 3": tienda3,
    "Tienda 4": tienda4
}

lista_res = []

for nombre, df in tiendas.items():
    top_n, bottom_n = top_y_bottom(df, nombre, n=5)
    lista_res.append(top_n)
    lista_res.append(bottom_n)

resumen_productos = pd.concat(lista_res, ignore_index=True)

# %%
resumen_productos
# Out:
#                        Producto  Cantidad_ventas    Tienda            Tipo
# 0                       Armario               60  Tienda 1    Más vendidos
# 1                 TV LED UHD 4K               60  Tienda 1    Más vendidos
# 2                    Microondas               60  Tienda 1    Más vendidos
# 3              Secadora de ropa               58  Tienda 1    Más vendidos
# 4                 Mesa de noche               56  Tienda 1    Más vendidos
# 5                       Mochila               39  Tienda 1  Menos vendidos
# 6                     Pandereta               36  Tienda 1  Menos vendidos
# 7               Olla de presión               35  Tienda 1  Menos vendidos
# 8                  Celular ABXY               33  Tienda 1  Menos vendidos
# 9     Auriculares con micrófono               33  Tienda 1  Menos vendidos
# 10    Iniciando en programación               65  Tienda 2    Más vendidos
# ...

# %%
tienda['Costo de envío'].mean()
# Out:
# np.float64(26018.60958033065)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
epro_t1 = tienda['Costo de envío'].mean()
epro_t2 = tienda2['Costo de envío'].mean()
epro_t3 = tienda3['Costo de envío'].mean()
epro_t4 = tienda4['Costo de envío'].mean()
df_epro = pd.DataFrame({
    "Tienda": ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"],
    "Costo de envío": [epro_t1,epro_t2,epro_t3,epro_t4]
}).set_index("Tienda")
df_epro['Costo de envío'] = df_epro['Costo de envío'].round(0)

# %%
px = df_epro.plot(kind= "bar",figsize = (8,4), color = "Green")
px.set_xlabel("Costo promedio de envio")
px.set_title("Costo promedio de envio por tienda")
px.bar_label(px.containers[0], padding=-10, color = "white")
plt.show()

# %% [markdown]
# #**Gráficas**

# %%
ax1 = df_ventas_categorias.plot(kind="bar", figsize=(9,5))
ax1.set_xlabel("Categoría del producto")
ax1.set_ylabel("Cantidad de ventas")
ax1.set_title("Ventas por categoría y tienda")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
ax2 = df_cal.plot(kind="bar", figsize=(7,4), color="orange", legend=False)
ax2.set_xlabel("Tienda")
ax2.set_ylabel("Calificación promedio")
ax2.set_title("Calificación promedio por tienda")
ax2.bar_label(ax2.containers[0], padding=3, color="black")
plt.ylim(0, 5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

datos_envio = [tienda["Costo de envío"],
               tienda2["Costo de envío"],
               tienda3["Costo de envío"],
               tienda4["Costo de envío"]]

labels = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]

fig, ax3 = plt.subplots(figsize=(7,4))
ax3.boxplot(datos_envio, labels=labels)
ax3.set_ylabel("Costo de envío")
ax3.set_title("Distribución del costo de envío por tienda")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2838343814.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax3.boxplot(datos_envio, labels=labels)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))

plt.scatter(tienda["Precio"], tienda["Costo de envío"], alpha=0.5, label="Tienda 1")
plt.scatter(tienda2["Precio"], tienda2["Costo de envío"], alpha=0.5, label="Tienda 2")
plt.scatter(tienda3["Precio"], tienda3["Costo de envío"], alpha=0.5, label="Tienda 3")
plt.scatter(tienda4["Precio"], tienda4["Costo de envío"], alpha=0.5, label="Tienda 4")

plt.xlabel("Precio del producto")
plt.ylabel("Costo de envío")
plt.title("Relación entre precio y costo de envío por tienda")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(tienda["Costo de envío"], tienda["Calificación"], alpha=0.5, label="Tienda 1")
plt.scatter(tienda2["Costo de envío"], tienda2["Calificación"], alpha=0.5, label="Tienda 2")
plt.scatter(tienda3["Costo de envío"], tienda3["Calificación"], alpha=0.5, label="Tienda 3")
plt.scatter(tienda4["Costo de envío"], tienda4["Calificación"], alpha=0.5, label="Tienda 4")

plt.xlabel("Costo de envío")
plt.ylabel("Calificación del cliente")
plt.title("Costo de envío vs. calificación por tienda")
plt.legend()
plt.tight_layout()
plt.show()

# %%
tienda['Precio']
# Out:
# 0        164300.0
# 1        192300.0
# 2        209600.0
# 3        757500.0
# 4        335200.0
#           ...
# 2354    1284400.0
# 2355     282800.0
# 2356     122900.0
# 2357     691300.0
# 2358     195000.0
# Name: Precio, Length: 2359, dtype: float64

# %%
plt.figure(figsize=(7,5))

plt.scatter(tienda["Precio"], tienda["Cantidad de cuotas"], alpha=0.5, label="Tienda 1")
plt.scatter(tienda2["Precio"], tienda2["Costo de envío"], alpha=0.5, label="Tienda 2")
plt.scatter(tienda3["Precio"], tienda3["Costo de envío"], alpha=0.5, label="Tienda 3")
plt.scatter(tienda4["Precio"], tienda4["Costo de envío"], alpha=0.5, label="Tienda 4")

plt.xlabel("Precio del producto")
plt.ylabel("Costo de envío")
plt.title("Relación entre precio y costo de envío por tienda")
plt.legend()
plt.tight_layout()
plt.show()
